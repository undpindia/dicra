# %%
import geopandas
# Out:
# C:\Users\Sandeep Gupta\anaconda3\envs\geo_env\lib\site-packages\pyproj\__init__.py:91: UserWarning: Valid PROJ data directory not found. Either set the path using the environmental variable PROJ_LIB or with `pyproj.datadir.set_data_dir`.
#   warnings.warn(str(err))

# %%
import geopandas as gpd
earthquake = gpd.read_file('C:\\vasu\Data4Policy-main\\Data4Policy-main\\Geospatial Data Science Internship\\Datasets\\telangana_shapefile.geojson')
print(earthquake)
# Out:
#   GID_0 NAME_0     GID_1     NAME_1 VARNAME_1 NL_NAME_1 TYPE_1 ENGTYPE_1  \
# 0   IND  India  IND.32_1  Telangana      None      None  State     State
#
#    CC_1 HASC_1                                           geometry
# 0  None  IN.TG  MULTIPOLYGON (((79.21147 16.36281, 79.22324 16...

# %%
import matplotlib

# %%
# %matplotlib inline
earthquake.plot(color="white", edgecolor='black')
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
df= pd.read_csv ('C:\\vasu\\a.csv')
print(df)
print(df.to_string())
# Out:
#        latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0       18.3777    80.5314       318.6   1.0    1.0  2015-01-02       802
# 1       17.5898    80.9893       315.4   1.2    1.1  2015-01-04       750
# 2       17.6028    81.1612       311.8   1.2    1.1  2015-01-05       527
# 3       17.5241    80.3135       317.0   1.1    1.0  2015-01-05       527
# 4       17.7571    80.3404       317.2   2.5    1.5  2015-01-05       833
# ...         ...        ...         ...   ...    ...         ...       ...
# 18780   18.3923    77.8257       315.4   1.0    1.0  2021-08-24       529
# 18781   18.4943    77.7611       317.2   1.0    1.0  2021-08-24       529
# 18782   18.4805    79.3012       314.0   1.9    1.3  2021-08-25       744
# 18783   17.9506    80.7815       316.8   2.1    1.4  2021-08-26       826
# 18784   18.0553    80.7812       318.4   2.1    1.4  2021-08-26       826
#
#       satellite instrument  confidence  version  bright_t31   frp daynight  \
# ...

# %%
df_gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))

# %%
# %matplotlib inline
earthquake.plot(color="white", edgecolor='black')
df_gdf.plot(color = 'Red')
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize = (10,8)) 
df_gdf.plot(color = 'Red', ax=ax)
earthquake.geometry.boundary.plot(edgecolor='k',linewidth = 4,ax=ax)
# Out:
# <AxesSubplot:>

# %%
dist = gpd.read_file('C:\\vasu\\India\\IND_adm\\IND_adm2.shp')
print(dist)
# Out:
#      ID_0  ISO NAME_0  ID_1               NAME_1  ID_2             NAME_2  \
# 0     105  IND  India     1  Andaman and Nicobar     1    Andaman Islands
# 1     105  IND  India     1  Andaman and Nicobar     2    Nicobar Islands
# 2     105  IND  India     2       Andhra Pradesh     3          Anantapur
# 3     105  IND  India     2       Andhra Pradesh     4           Chittoor
# 4     105  IND  India     2       Andhra Pradesh     5           Cuddapah
# ..    ...  ...    ...   ...                  ...   ...                ...
# 589   105  IND  India    36          West Bengal   590  North 24 Parganas
# 590   105  IND  India    36          West Bengal   591           Puruliya
# 591   105  IND  India    36          West Bengal   592  South 24 Parganas
# 592   105  IND  India    36          West Bengal   593     Uttar Dinajpur
# 593   105  IND  India    36          West Bengal   594     West Midnapore
#
#        TYPE_2 ENGTYPE_2 NL_NAME_2             VARNAME_2  \
# ...

# %%
# %matplotlib inline
dist.plot(color="white", edgecolor='black')
# Out:
# <AxesSubplot:>

# %%
abc=dist[dist.NAME_1 == 'Telangana']
print (abc)
# Out:
#      ID_0  ISO NAME_0  ID_1     NAME_1  ID_2       NAME_2    TYPE_2 ENGTYPE_2  \
# 478   105  IND  India    32  Telangana   479     Adilabad  District  District
# 479   105  IND  India    32  Telangana   480    Hyderabad  District  District
# 480   105  IND  India    32  Telangana   481   Karimnagar  District  District
# 481   105  IND  India    32  Telangana   482      Khammam  District  District
# 482   105  IND  India    32  Telangana   483  Mahbubnagar  District  District
# 483   105  IND  India    32  Telangana   484        Medak  District  District
# 484   105  IND  India    32  Telangana   485     Nalgonda  District  District
# 485   105  IND  India    32  Telangana   486    Nizamabad  District  District
# 486   105  IND  India    32  Telangana   487   Rangareddi  District  District
# 487   105  IND  India    32  Telangana   488     Warangal  District  District
#
#     NL_NAME_2                  VARNAME_2  \
# 478      None                       None
# ...

# %%
abc.plot()
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize = (10,8)) 
df_gdf.plot(color = 'Red', ax=ax)
abc.geometry.boundary.plot(edgecolor='k',linewidth = 4,ax=ax)
# Out:
# <AxesSubplot:>

# %%
df_gdf_joined = gpd.sjoin(left_df=df_gdf,
                                   right_df=abc,
                                   how="inner", op='within')
df_gdf_joined.head()
# Out:
# C:\Users\Sandeep Gupta\anaconda3\envs\geo_env\lib\site-packages\IPython\core\interactiveshell.py:3301: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# C:\Users\Sandeep Gupta\AppData\Local\Temp\ipykernel_9144\747116628.py:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   df_gdf_joined = gpd.sjoin(left_df=df_gdf,
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0   18.3777    80.5314       318.6   1.0    1.0  2015-01-02       802
# 1   17.5898    80.9893       315.4   1.2    1.1  2015-01-04       750
# 2   17.6028    81.1612       311.8   1.2    1.1  2015-01-05       527
# ...

# %%
print (df_gdf_joined)
# Out:
#        latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0       18.3777    80.5314       318.6   1.0    1.0  2015-01-02       802
# 1       17.5898    80.9893       315.4   1.2    1.1  2015-01-04       750
# 2       17.6028    81.1612       311.8   1.2    1.1  2015-01-05       527
# 3       17.5241    80.3135       317.0   1.1    1.0  2015-01-05       527
# 4       17.7571    80.3404       317.2   2.5    1.5  2015-01-05       833
# ...         ...        ...         ...   ...    ...         ...       ...
# 3386    17.3018    78.4681       332.1   1.0    1.0  2016-03-07       814
# 4127    17.3260    78.4991       318.7   1.0    1.0  2016-10-15       521
# 11582   17.4458    78.4651       326.9   1.8    1.3  2019-03-04       750
# 12203   17.3773    78.4591       310.8   1.1    1.1  2019-03-20      1715
# 13250   17.3173    78.4937       316.1   1.0    1.0  2020-02-04       527
#
#       satellite instrument  confidence  ...  ISO  NAME_0  ID_1     NAME_1  \
# ...

# %%
import pandas as pd
import numpy as np


print(df_gdf_joined[['NAME_2', 'acq_date']])

# %%
df_gdf_joined['count'] = df_gdf_joined['NAME_2'].value_counts()

# %%
df_gdf_joined['acq_date'] = pd.to_datetime(df_gdf_joined.acq_date, format='%Y-%m-%d')

# %%
df_gdf_joined['Year'] = df_gdf_joined['acq_date'].dt.strftime('%Y')

# %%
df_gdf_joined[['NAME_2','Year']].groupby(['NAME_2','Year']).size()
# Out:
# NAME_2    Year
# Adilabad  2015    276
#           2016    293
#           2017    499
#           2018    549
#           2019    290
#                  ...
# Warangal  2017    632
#           2018    665
#           2019    314
#           2020    383
#           2021    484
# Length: 67, dtype: int64
