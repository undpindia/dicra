# %% [markdown]
# { “Sheet1”: \[ { “Count ID”: “C1”, “adm_name”: “Adilabad”, “year”: 2015,
# “fireCount”: “Point”, “year_1”: 2015 }, { “Count ID”: “C2”, “adm_name”:
# “Adilabad”, “year”: 2015, “fireCount”: “Point”, “year_1”: 2015 }, {
# “Count ID”: “C3”, “adm_name”: “Adilabad”, “year”: 2015, “fireCount”:
# “Point”, “year_1”: 2015 }, { “Count ID”: “C4”, “adm_name”: “Adilabad”,
# “year”: 2015, “fireCount”: “Point”, “year_1”: 2015 }, { “Count ID”:
# “C5”, “adm_name”: “Adilabad”, “year”: 2015, “fireCount”: “Point”,
# “year_1”: 2015 }, { “Count ID”: “C6”, “adm_name”: “Adilabad”, “year”:
# 2015, “fireCount”: “Point”, “year_1”: 2015 }, { “Count ID”: “C7”,
# “adm_name”: “Adilabad”, “year”: 2015, “fireCount”: “Point”, “year_1”:
# 2015 }, { “Count ID”: “C8”, “adm_name”: “Adilabad”, “year”: 2015,
# “fireCount”: “Point”, “year_1”: 2015 }, { “Count ID”: “C9”, “adm_name”:
# “Adilabad”, “year”: 2015, “fireCount”: “Point”, “year_1”: 2015 }, {
# “Count ID”: “C10”, “adm_name”: “Adilabad”, “year”: 2015, “fireCount”:
# “Point”, “year_1”: 2015 }, { “Count ID”: “C11”, “adm_name”: “Adilabad”,
# “year”: 2015, “fireCount”: “Point”, “year_1”: 2015 }, { “Count ID”:
# “C12”, “adm_name”: “Adilabad”, “year”: 2015, “fireCount”: “Point”,
# “year_1”: 2015 }, { “Count ID”: “C13”, “adm_name”: “Adilabad”, “year”:
# 2015, “fireCount”: “Point”, “year_1”: 2015 }, { “Count ID”: “C14”,
# “adm_name”: “Adilabad”, “year”: 2015, “fireCount”: “Point”, “year_1”:
# 2015 }, { “Count ID”: “C15”, “adm_name”: “Adilabad”, “year”: 2015,
# “fireCount”: “Point”, “year_1”: 2015 }, { “Count ID”: “C16”, “adm_name”:
# “Adilabad”, “year”: 2015, “fireCount”: “Point”, “year_1”: 2015 }, {
# “Count ID”: “C17”, “adm_name”: “Adilabad”, “year”: 2015, “fireCount”:
# “Point”, “year_1”: 2015 }, { “Count ID”: “C18”, “adm_name”: “Adilabad”,
# “year”: 2016, “fireCount”: “Point”, “year_1”: 2016 }, { “Count ID”:
# “C19”, “adm_name”: “Adilabad”, “year”: 2016, “fireCount”: “Point”,
# “year_1”: 2016 }, { “Count ID”: “C20”, “adm_name”: “Adilabad”, “year”:
# 2016, “fireCount”: “Point”, “year_1”: 2016 }, { “Count ID”: “C21”,
# “adm_name”: “Adilabad”, “year”: 2016, “fireCount”: “Point”, “year_1”:
# 2016 }, { “Count ID”: “C22”, “adm_name”: “Adilabad”, “year”: 2016,
# “fireCount”: “Point”, “year_1”: 2016 }, { “Count ID”: “C23”, “adm_name”:
# “Adilabad”, “year”: 2016, “fireCount”: “Point”, “year_1”: 2016 }, {
# “Count ID”: “C24”, “adm_name”: “Adilabad”, “year”: 2016, “fireCount”:
# “Point”, “year_1”: 2016 }, { “Count ID”: “C25”, “adm_name”: “Adilabad”,
# “year”: 2016, “fireCount”: “Point”, “year_1”: 2016 }, { “Count ID”:
# “C26”, “adm_name”: “Adilabad”, “year”: 2016, “fireCount”: “Point”,
# “year_1”: 2016 }, { “Count ID”: “C27”, “adm_name”: “Adilabad”, “year”:
# 2016, “fireCount”: “Point”, “year_1”: 2016 }, { “Count ID”: “C28”,
# “adm_name”: “Adilabad”, “year”: 2016, “fireCount”: “Point”, “year_1”:
# 2016 }, { “Count ID”: “C29”, “adm_name”: “Adilabad”, “year”: 2016,
# “fireCount”: “Point”, “year_1”: 2016 }, { “Count ID”: “C30”, “adm_name”:
# “Adilabad”, “year”: 2016, “fireCount”: “Point”, “year_1”: 2016 }, {
# “Count ID”: “C31”, “adm_name”: “Adilabad”, “year”: 2016, “fireCount”:
# “Point”, “year_1”: 2016 }, { “Count ID”: “C32”, “adm_name”: “Adilabad”,
# “year”: 2016, “fireCount”: “Point”, “year_1”: 2016 }, { “Count ID”:
# “C33”, “adm_name”: “Adilabad”, “year”: 2016, “fireCount”: “Point”,
# “year_1”: 2016 }, { “Count ID”: “C34”, “adm_name”: “Adilabad”, “year”:
# 2016, “fireCount”: “Point”, “year_1”: 2016 }, { “Count ID”: “C35”,
# “adm_name”: “Adilabad”, “year”: 2016, “fireCount”: “Point”, “year_1”:
# 2016 }, { “Count ID”: “C36”, “adm_name”: “Adilabad”, “year”: 2017,
# “fireCount”: “Point”, “year_1”: 2017 } \] }
