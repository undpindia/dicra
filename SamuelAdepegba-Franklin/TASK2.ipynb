# %% [markdown]
# { “Sheet1”: \[ {
# "\_\_EMPTY“:”fireID“,”\_\_EMPTY_1“:”adm_name“,”\_\_EMPTY_2“:”year“,”\_\_EMPTY_3“:”fireCount“,”\_\_EMPTY_4“:”class
# (1,0)" }, { "\_\_EMPTY“:”f1“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2015,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 1 },
# {”\_\_EMPTY“:”f2“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2015,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 1 },
# {”\_\_EMPTY“:”f3“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2015,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 1 },
# {”\_\_EMPTY“:”f4“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2015,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 1 },
# {”\_\_EMPTY“:”f5“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2015,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 1 },
# {”\_\_EMPTY“:”f6“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2015,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 1 },
# {”\_\_EMPTY“:”f7“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2015,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 1 },
# {”\_\_EMPTY“:”f8“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2015,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f9“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2015,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f10“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2015,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f11“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2015,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f12“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2015,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f13“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2015,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f14“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2015,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f15“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2015,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 1 },
# {”\_\_EMPTY“:”f16“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2015,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 1 },
# {”\_\_EMPTY“:”f17“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2015,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 1 },
# {”\_\_EMPTY“:”f18“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2016,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f19“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2016,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f20“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2016,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f21“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2016,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 1 },
# {”\_\_EMPTY“:”f22“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2016,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 1 },
# {”\_\_EMPTY“:”f23“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2016,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 1 },
# {”\_\_EMPTY“:”f24“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2016,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 1 },
# {”\_\_EMPTY“:”f25“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2016,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f26“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2016,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f27“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2016,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f28“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2016,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f29“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2016,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f30“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2016,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f31“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2016,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 1 },
# {”\_\_EMPTY“:”f32“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2016,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 1 },
# {”\_\_EMPTY“:”f33“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2016,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f34“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2016,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f35“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2016,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4“: 0 },
# {”\_\_EMPTY“:”f36“,”\_\_EMPTY_1“:”Adilabad“,”\_\_EMPTY_2“:
# 2017,”\_\_EMPTY_3“:”Point“,”\_\_EMPTY_4": 1 } \] }
