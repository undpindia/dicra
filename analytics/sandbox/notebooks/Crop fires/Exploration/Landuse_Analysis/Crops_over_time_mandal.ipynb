# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import os
import geopandas as gpd
import geoplot
import geoplot.crs as gcrs
import matplotlib.pyplot as plt
from shapely.geometry import Point
import folium
import rasterio
import numpy as np
import datetime as dt
from rasterstats import zonal_stats
from matplotlib import pyplot

oldpwd = os.getcwd()

# %%
mandal_boundaries = gpd.read_file('../../../../../../src/data_preprocessing/tsdm/Mandal_Boundary.shp')
mandal_boundaries = mandal_boundaries.reset_index()

shape_telangana = gpd.read_file('../../../../../../src/data_preprocessing/base_geojson/TL_state_shapefile_for_clip.geojson')
shape_telangana = shape_telangana.explode()

# %%
def crop_counts(boundaries, year):
    tiff = '../../../../../../src/data_preprocessing/LULC/01-01-'+str(year)+'.tif'
    lulc = rasterio.open(tiff, mode = 'r')
    lulc_array = lulc.read(1) # landuse corresponding to each rasterpixel, so we extracted the pixel values from the raster
    # affine: 1: corresponds to the width of each pixel, 2: row rotation, 3: x-coordinate of the upper left pixel, 4: column rotation, 5: height of each pixel, 6: y-coordinate of the upper left pixel
    affine = lulc.transform

    cmap = {1: 'Water', 2: 'Trees', 4: 'Flooded Vegetation', 5: 'Crops', 7: 'Built Area', 8: 'Bare Ground', 9: 'Snow/Ice', 10: 'Clouds', 11: 'Rangeland'}
    boundaries['Crops ' + str(year)] = 0
    boundaries['Flooded Vegetation ' + str(year)] = 0

    test = zonal_stats(boundaries.geometry, lulc_array, affine = affine, geojson_out = True, nodata = lulc.nodata, categorical=True, category_map = cmap)

    for i in range(0, len(test)):
        try:
            boundaries['Crops ' + str(year)].iloc[i] = test[i]['properties']['Crops']  * 0.0001
        except:
            boundaries['Crops ' + str(year)].iloc[i] = 0
        try:
            boundaries['Flooded Vegetation ' + str(year)].iloc[i] = test[i]['properties']['Flooded Vegetation']  * 0.0001
        except:
            boundaries['Flooded Vegetation ' + str(year)].iloc[i] = 0
        
    return (boundaries)

# %%
for a in range(2017, 2022):
    mandal_boundaries = crop_counts(mandal_boundaries, a)
    print('Year ' + str(a) + ' is completed.')
# Out:
# Year 2017 is completed.
# Year 2018 is completed.
# Year 2019 is completed.
# Year 2020 is completed.
# Year 2021 is completed.

# %%
mandal_boundaries
# Out:
#      index   Area   S_No    No_HH     TOT_P    TOT_M    TOT_F     P_06  \
# 0        0  255.0  415.0  37246.0  156067.0  79754.0  76313.0  17498.0
# 1        1  502.0  278.0  15679.0   69875.0  36019.0  33856.0   8986.0
# 2        2  126.0  298.0   4267.0   17249.0   8827.0   8422.0   2261.0
# 3        3  142.0  573.0   6618.0   25849.0  12901.0  12948.0   2482.0
# 4        4  134.0  201.0   6256.0   31224.0  15739.0  15485.0   4056.0
# ..     ...    ...    ...      ...       ...      ...      ...      ...
# 587    587  244.0  373.0   3304.0   13452.0   6514.0   6938.0   1365.0
# 588    588  244.0  363.0   2532.0   10878.0   5359.0   5519.0   1272.0
# 589    589  249.0  460.0  11364.0   51386.0  25737.0  25649.0   6220.0
# 590    590  212.0  253.0   9516.0   42309.0  20842.0  21467.0   5078.0
# 591    591  181.0  480.0   9143.0   38731.0  19255.0  19476.0   3729.0
#
#        M_06    F_06  ...  Crops 2017  Flooded Vegetation 2017  Crops 2018  \
# 0    9151.0  8347.0  ...     84.9836                   0.0144     80.2551
# 1    4726.0  4260.0  ...    197.5611                   0.0000    207.8593
# 2    1193.0  1068.0  ...     81.2996                   0.0016     86.1867
# 3    1234.0  1248.0  ...    126.8147                   0.0285    130.0430
# 4    2061.0  1995.0  ...    108.2324                   0.0931    113.0839
# ..      ...     ...  ...         ...                      ...         ...
# 587   698.0   667.0  ...     23.9109                   0.0006     24.5527
# 588   653.0   619.0  ...     30.0628                   0.0209     30.0674
# 589  3186.0  3034.0  ...     83.2802                   0.5067     87.7785
# 590  2611.0  2467.0  ...     45.3161                   0.0000     48.8000
# 591  1901.0  1828.0  ...     67.9970                   0.0000     68.8364
#
#      Flooded Vegetation 2018  Crops 2019  Flooded Vegetation 2019  Crops 2020  \
# 0                     0.0019     90.2137                   0.0000     76.1404
# 1                     0.0000    183.9440                   0.0000    206.6133
# 2                     0.0004     84.7520                   0.0000     84.4137
# 3                     0.0000    132.8201                   0.0000    129.4461
# 4                     0.0015    102.6739                   0.0000    113.9548
# ..                       ...         ...                      ...         ...
# 587                   0.0000     24.7084                   0.0000     24.2441
# 588                   0.0000     30.1379                   0.0005     31.8042
# 589                   0.0335     90.3907                   0.0000     90.9823
# 590                   0.0000     49.3215                   0.0000     47.6468
# 591                   0.0000     68.9191                   0.0000     68.1570
#
#      Flooded Vegetation 2020 Crops 2021 Flooded Vegetation 2021
# 0                     0.0007    84.4641                  0.4703
# 1                     0.0000   218.2740                  0.0102
# 2                     0.0035    88.9952                  0.0055
# 3                     0.0000   129.6141                  0.1054
# 4                     0.2054   115.9068                  0.0000
# ..                       ...        ...                     ...
# 587                   0.0083    24.7101                  0.0056
# 588                   0.0472    32.0116                  0.0314
# 589                   0.0000    87.2330                  0.0010
# 590                   0.0000    48.6953                  0.0000
# 591                   0.0000    68.0995                  0.0000
#
# [592 rows x 32 columns]

# %%
crops_over_time_mandal = mandal_boundaries[['geometry', 'Crops 2017', 'Crops 2018', 'Crops 2019', 'Crops 2020', 'Crops 2021',  'Flooded Vegetation 2017', 'Flooded Vegetation 2018', 'Flooded Vegetation 2019' ,'Flooded Vegetation 2020' ,'Flooded Vegetation 2021' ]]

# %%
crops_over_time_mandal['2017'] = crops_over_time_mandal['Crops 2017'] + crops_over_time_mandal['Flooded Vegetation 2017']
crops_over_time_mandal['2018'] = crops_over_time_mandal['Crops 2018'] + crops_over_time_mandal['Flooded Vegetation 2018']
crops_over_time_mandal['2019'] = crops_over_time_mandal['Crops 2019'] + crops_over_time_mandal['Flooded Vegetation 2019']
crops_over_time_mandal['2020'] = crops_over_time_mandal['Crops 2020'] + crops_over_time_mandal['Flooded Vegetation 2020']
crops_over_time_mandal['2021'] = crops_over_time_mandal['Crops 2021'] + crops_over_time_mandal['Flooded Vegetation 2021']
crops_over_time_mandal = crops_over_time_mandal[['geometry', '2017', '2018', '2019', '2020', '2021']]

# %%
#crops_over_time_mandal = crops_over_time_mandal.reset_index()
fig, (axs) = pyplot.subplots(ncols=3, figsize=(12,4))
axs=axs.ravel()

axs[0].axis('off')
axs[0].set_title('2017')
crops_over_time_mandal.plot(ax = axs[0], column = '2017')

axs[1].axis('off')
axs[1].set_title('2018')
crops_over_time_mandal.plot(ax = axs[1], column = '2018')

axs[2].axis('off')
axs[2].set_title('2019')
crops_over_time_mandal.plot(ax = axs[2], column = '2019')

axs[0].axis('off')
axs[0].set_title('2020')
crops_over_time_mandal.plot(ax = axs[0], column = '2020')

axs[1].axis('off')
axs[1].set_title('2021')
crops_over_time_mandal.plot(ax = axs[1], column = '2021')


patch_col = axs[0].collections[0]
cb = fig.colorbar(patch_col, ax=axs, shrink = 0.75)
fig.suptitle('Crop Area km2')
plt.show()

# %%
plt.plot(['2017', '2018', '2019','2020','2021'], [crops_over_time_mandal['2017'].sum(), crops_over_time_mandal['2018'].sum() , crops_over_time_mandal['2019'].sum(), crops_over_time_mandal['2020'].sum(), crops_over_time_mandal['2021'].sum()])
plt.title('Area Crops Over Time')
plt.ylim([0, 80000])
plt.xlabel('Year')
plt.ylabel('Area km2')
plt.show()

# %%
fig = plt.figure(figsize = (20,18))

for i in range(0, len(mandal_boundaries)):
    x_axis = ['01-01-2017', '01-01-2018', '01-01-2019', '01-01-2020', '01-01-2021']
    y_axis = crops_over_time_mandal.loc[i].to_list()[1:]
    plt.plot(x_axis, y_axis)

plt.title('Amount of Crop Area per Mandal')
plt.xlabel('Date')
plt.ylabel('Crop Area (Amount of pixels)')
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller     
from statsmodels.tsa.stattools import kpss

adf_test = []
kpss_test = []
for i in range(0, len(mandal_boundaries)):
    X = crops_over_time_mandal.loc[i][1:]
    result = adfuller(X)
    adf_test.append(result[1])

    try:
        kpsstest = kpss(X, regression='c', nlags="auto")
        kpss_output = pd.Series(kpsstest[0:3], index=['Test Statistic','p-value','#Lags Used'])
        kpss_test.append(kpss_output[1])
    except:
        kpss_test.append(0.1)

# %%
fig = plt.figure(figsize = (20,18))

for i in range(0, len(mandal_boundaries)):
    kpss_test[i]
    if (kpss_test[i]<0.05) & (adf_test[i]>0.05):
        x_axis = ['01-01-2017', '01-01-2018', '01-01-2019', '01-01-2020', '01-01-2021']
        y_axis = crops_over_time_mandal.loc[i].to_list()[1:]
        plt.plot(x_axis, y_axis)

plt.title('Amount of Crop Area per Mandal')
plt.xlabel('Date')
plt.ylabel('Crop Area (Amount of pixels)')
plt.show()

# %%
crops_over_time_mandal.mean(axis = 1).plot()
plt.ylim(1000000, 1300000)
plt.title('Average Amount of Crops per Mandal')
plt.ylabel('Crops (Amount of Pixels)')
plt.show()

# %%
plot_mean =gpd.GeoDataFrame()
plot_mean['Mandal_Nam'] = list(mandal_boundaries.Mandal_Nam)
plot_mean['mean_value']  = crops_over_time_mandal.mean(axis = 1)
plot_mean['geometry'] = crops_over_time_mandal['geometry']
#plot_mean = plot_mean.set_geometry(plot_mean["geometry"])

# %%
plot_mean.plot(column='mean_value')
# Out:
# <AxesSubplot:>

# %%
ax = plot_mean.mean_value.plot(xticks=plot_mean.index, rot=90, figsize=(50, 20),)
ax.set_xticklabels(plot_mean.Mandal_Nam)
# Out:
# [Text(0, 0, 'Abdullapurmet'),
#  Text(1, 0, 'Achampet'),
#  Text(2, 0, 'Adavidevulapally'),
#  Text(3, 0, 'Addagudur'),
#  Text(4, 0, 'Addakal'),
#  Text(5, 0, 'Adilabad Rural'),
#  Text(6, 0, 'Adilabad Urban'),
#  Text(7, 0, 'Aiza'),
#  Text(8, 0, 'Akkannapet'),
#  Text(9, 0, 'Alair'),
#  Text(10, 0, 'Alampur'),
#  Text(11, 0, 'Alladurg'),
#  Text(12, 0, 'Allapalli'),
#  Text(13, 0, 'Alwal'),
#  Text(14, 0, 'Amangal'),
#  Text(15, 0, 'Amarchintha'),
#  Text(16, 0, 'Amberpet'),
#  Text(17, 0, 'Ammerpet'),
#  Text(18, 0, 'Amrabad'),
#  Text(19, 0, 'Ananthagiri'),
#  Text(20, 0, 'Andole'),
#  Text(21, 0, 'Annapureddipalle'),
#  Text(22, 0, 'Anumula_Haliya'),
#  Text(23, 0, 'Armoor'),
#  Text(24, 0, 'Asifabad'),
#  Text(25, 0, 'Asifnagar'),
#  Text(26, 0, 'Aswapuram'),
#  Text(27, 0, 'Aswaraopeta'),
#  Text(28, 0, 'Athmakur (M)'),
#  Text(29, 0, 'Atmakur'),
#  Text(30, 0, 'Atmakur'),
#  Text(31, 0, 'Atmakur_S'),
#  Text(32, 0, 'B.Pochampally'),
#  Text(33, 0, 'Bachannapet'),
#  Text(34, 0, 'Bachupally'),
#  Text(35, 0, 'Bahadurpura'),
#  Text(36, 0, 'Balanagar'),
#  Text(37, 0, 'Balanagar'),
#  Text(38, 0, 'Balapur'),
#  Text(39, 0, 'Balkonda'),
#  Text(40, 0, 'Balmoor'),
#  Text(41, 0, 'Bandlaguda'),
#  Text(42, 0, 'Banswada'),
#  Text(43, 0, 'Bantwaram'),
#  Text(44, 0, 'Basar'),
#  Text(45, 0, 'Basheerabad'),
#  Text(46, 0, 'Bayyaram'),
#  Text(47, 0, 'Bazarhathnoor'),
#  Text(48, 0, 'Beerpur'),
#  Text(49, 0, 'Bejjanki'),
#  Text(50, 0, 'Bejjur'),
#  Text(51, 0, 'Bela'),
#  Text(52, 0, 'Bellampalle'),
#  Text(53, 0, 'Bhadrachalam'),
#  Text(54, 0, 'Bhainsa'),
#  Text(55, 0, 'Bheemadevarapalli'),
#  Text(56, 0, 'Bheemaram'),
#  Text(57, 0, 'Bheemgal'),
#  Text(58, 0, 'Bheemini'),
#  Text(59, 0, 'Bheempoor'),
#  Text(60, 0, 'Bhiknoor'),
#  Text(61, 0, 'Bhongiri'),
#  Text(62, 0, 'Bhoothpur'),
#  Text(63, 0, 'Bhupalpally'),
#  Text(64, 0, 'Bibinagar'),
#  Text(65, 0, 'Bibipet'),
#  Text(66, 0, 'Bijinapalle'),
#  Text(67, 0, 'Boath'),
#  Text(68, 0, 'Bodhan'),
#  Text(69, 0, 'Boinpalli'),
#  Text(70, 0, 'Bommalaramaram'),
#  Text(71, 0, 'Bommaraspeta'),
#  Text(72, 0, 'Bonakal'),
#  Text(73, 0, 'Buggaram'),
#  Text(74, 0, 'Burgampadu'),
#  Text(75, 0, 'Chandampet'),
#  Text(76, 0, 'Chandrugonda'),
#  Text(77, 0, 'Chandur'),
#  Text(78, 0, 'Charakonda'),
#  Text(79, 0, 'Charminar'),
#  Text(80, 0, 'Chendurthi'),
#  Text(81, 0, 'Chennaraopet'),
#  Text(82, 0, 'Chennur'),
#  Text(83, 0, 'Cherial'),
#  Text(84, 0, 'Cherla'),
#  Text(85, 0, 'Chevella'),
#  Text(86, 0, 'Chigurumamidi'),
#  Text(87, 0, 'Chilkur'),
#  Text(88, 0, 'Chilpur'),
#  Text(89, 0, 'Chinna Chinta Kunta'),
#  Text(90, 0, 'Chinnagudur'),
#  Text(91, 0, 'Chinnakodur'),
#  Text(92, 0, 'Chinnambavi'),
#  Text(93, 0, 'Chintakani'),
#  Text(94, 0, 'Chintalamanepally'),
#  Text(95, 0, 'Chinthala palem'),
#  Text(96, 0, 'Chinthapally'),
#  Text(97, 0, 'Chityal'),
#  Text(98, 0, 'Chityal'),
#  Text(99, 0, 'Chivvemla'),
#  Text(100, 0, 'Choppadandi'),
#  Text(101, 0, 'Choutuppal'),
#  Text(102, 0, 'Chowdergudem'),
#  Text(103, 0, 'Chunchupally'),
#  Text(104, 0, 'Dahegaon'),
#  Text(105, 0, 'Damaracherla'),
#  Text(106, 0, 'Damargidda'),
#  Text(107, 0, 'Damera'),
#  Text(108, 0, 'Dammapeta'),
#  Text(109, 0, 'Dandepalle'),
#  Text(110, 0, 'Danthalapalle'),
#  Text(111, 0, 'Dasturabad'),
#  Text(112, 0, 'Devarakonda'),
#  Text(113, 0, 'Devarkadra'),
#  Text(114, 0, 'Devaruppula'),
#  Text(115, 0, 'Dhanwada'),
#  Text(116, 0, 'Dharmapuri'),
#  Text(117, 0, 'Dharmaram'),
#  Text(118, 0, 'Dharmasagar'),
#  Text(119, 0, 'Dharoor'),
#  Text(120, 0, 'Dharoor'),
#  Text(121, 0, 'Dharpally'),
#  Text(122, 0, 'Dichpally'),
#  Text(123, 0, 'Dilawarpur'),
#  Text(124, 0, 'Doma'),
#  Text(125, 0, 'Dornakal'),
#  Text(126, 0, 'Doulthabad'),
#  Text(127, 0, 'Dubbak'),
#  Text(128, 0, 'Duggondi'),
#  Text(129, 0, 'Dummugudem'),
#  Text(130, 0, 'Dundigal Gandimaisamma'),
#  Text(131, 0, 'Eligaid'),
#  Text(132, 0, 'Elkathurthi'),
#  Text(133, 0, 'Ellandakunta'),
#  Text(134, 0, 'Enkoor'),
#  Text(135, 0, 'Eturnagaram'),
#  Text(136, 0, 'Farooqnagar'),
#  Text(137, 0, 'Gadiguda'),
#  Text(138, 0, 'Gadwal'),
#  Text(139, 0, 'Gajwel'),
#  Text(140, 0, 'Gambhiraopet'),
#  Text(141, 0, 'Gandeed'),
#  Text(142, 0, 'Gandhari'),
#  Text(143, 0, 'Gandipet'),
#  Text(144, 0, 'Gangadhara'),
#  Text(145, 0, 'Gangaram'),
#  Text(146, 0, 'Ganneruvaram'),
#  Text(147, 0, 'Garidepalli'),
#  Text(148, 0, 'Garla'),
#  Text(149, 0, 'Geesugonda'),
#  Text(150, 0, 'Ghanapur_Mulug'),
#  Text(151, 0, 'Ghanpur'),
#  Text(152, 0, 'Ghanpur (Stn)'),
#  Text(153, 0, 'Ghatkesar'),
#  Text(154, 0, 'Ghattu'),
#  Text(155, 0, 'Golkonda'),
#  Text(156, 0, 'Gollapalli'),
#  Text(157, 0, 'Gopalpet'),
#  Text(158, 0, 'Govindaraopet'),
#  Text(159, 0, 'Gudihathnur'),
#  Text(160, 0, 'Gudur'),
#  Text(161, 0, 'Gummadidala'),
#  Text(162, 0, 'Gundala'),
#  Text(163, 0, 'Gundala'),
#  Text(164, 0, 'Gundlapally'),
#  Text(165, 0, 'Gurrampode'),
#  Text(166, 0, 'Hajipur'),
#  Text(167, 0, 'Hanamkonda'),
#  Text(168, 0, 'Hanwada'),
#  Text(169, 0, 'Hasanparthy'),
#  Text(170, 0, 'Hathnoora'),
#  Text(171, 0, 'Havelighanpur'),
#  Text(172, 0, 'Hayathnagar'),
#  Text(173, 0, 'Himayatnagar'),
#  Text(174, 0, 'Husnabad'),
#  Text(175, 0, 'Huzur nagar'),
#  Text(176, 0, 'Huzurabad'),
#  Text(177, 0, 'Ibrahimpatnam'),
#  Text(178, 0, 'Ibrahimpatnam'),
#  Text(179, 0, 'Ichoda'),
#  Text(180, 0, 'Illanthakunta'),
#  Text(181, 0, 'Inavolu'),
#  Text(182, 0, 'Indalwai'),
#  Text(183, 0, 'Inderavelly'),
#  Text(184, 0, 'Itikyal'),
#  Text(185, 0, 'Jadcherla'),
#  Text(186, 0, 'Jagdevpur'),
#  Text(187, 0, 'Jagityal_Rural'),
#  Text(188, 0, 'Jagtial'),
#  Text(189, 0, 'Jainad'),
#  Text(190, 0, 'Jainoor'),
#  Text(191, 0, 'Jaipur'),
#  Text(192, 0, 'Jajireddigudem'),
#  Text(193, 0, 'Jakranpally'),
#  Text(194, 0, 'Jammikunta'),
#  Text(195, 0, 'Jangoan'),
#  Text(196, 0, 'Jannaram'),
#  Text(197, 0, 'Jharasangam'),
#  Text(198, 0, 'Jukkal'),
#  Text(199, 0, 'Julapalli'),
#  Text(200, 0, 'Julurupad'),
#  Text(201, 0, 'Kaddampeddur'),
#  Text(202, 0, 'Kadthal'),
#  Text(203, 0, 'Kagaznagar'),
#  Text(204, 0, 'Kalher'),
#  Text(205, 0, 'Kalluru'),
#  Text(206, 0, 'Kaloor_Thimmandoddi'),
#  Text(207, 0, 'Kalwakurthy'),
#  Text(208, 0, 'Kamalapur'),
#  Text(209, 0, 'Kamanpur'),
#  Text(210, 0, 'Kamareddy'),
#  Text(211, 0, 'Kamepally'),
#  Text(212, 0, 'Kanagal'),
#  Text(213, 0, 'Kandi'),
#  Text(214, 0, 'Kandukur'),
#  Text(215, 0, 'Kangti'),
#  Text(216, 0, 'Kannaigudem'),
#  Text(217, 0, 'Kannepalli'),
#  Text(218, 0, 'Kapra'),
#  Text(219, 0, 'Karakagudem'),
#  Text(220, 0, 'Karimnagar'),
#  Text(221, 0, 'Karimnagar_Rural'),
#  Text(222, 0, 'Kasipet'),
#  Text(223, 0, 'Kataram'),
#  Text(224, 0, 'Kathlapur'),
#  Text(225, 0, 'Kattangur'),
#  Text(226, 0, 'Keesara'),
#  Text(227, 0, 'Kerameri'),
#  Text(228, 0, 'Kesamudram'),
#  Text(229, 0, 'Keshampeta'),
#  Text(230, 0, 'Kethepally'),
#  Text(231, 0, 'Khaazipet'),
#  Text(232, 0, 'Khairatabad'),
#  Text(233, 0, 'Khammam_Rural'),
#  Text(234, 0, 'Khammam_Urban'),
#  Text(235, 0, 'Khanapur'),
#  Text(236, 0, 'Khanapur'),
#  Text(237, 0, 'Khila Warangal'),
#  Text(238, 0, 'Kodad'),
#  Text(239, 0, 'Kodair'),
#  Text(240, 0, 'Kodangal'),
#  Text(241, 0, 'Kodimial'),
#  Text(242, 0, 'Koheda'),
#  Text(243, 0, 'Kohir'),
#  Text(244, 0, 'Koilkonda'),
#  Text(245, 0, 'Kollapur'),
#  Text(246, 0, 'Komuravelli'),
#  Text(247, 0, 'Konaraopet'),
#  Text(248, 0, 'Kondamallapally'),
#  Text(249, 0, 'Kondapak'),
#  Text(250, 0, 'Kondapur'),
#  Text(251, 0, 'Kondurg'),
#  Text(252, 0, 'Konijerla'),
#  Text(253, 0, 'Korutla'),
#  Text(254, 0, 'Kosgi'),
#  Text(255, 0, 'Kotagiri'),
#  Text(256, 0, 'Kotepally'),
#  Text(257, 0, 'Kothaguda'),
#  Text(258, 0, 'Kothagudem'),
#  Text(259, 0, 'Kothakota'),
#  Text(260, 0, 'Kothapally'),
#  Text(261, 0, 'Kothur'),
#  Text(262, 0, 'Kouthala'),
#  Text(263, 0, 'Kowdipally'),
#  Text(264, 0, 'Kubeer'),
#  Text(265, 0, 'Kukatpally'),
#  Text(266, 0, 'Kulcharam'),
#  Text(267, 0, 'Kulkacharla'),
#  Text(268, 0, 'Kuntala'),
#  Text(269, 0, 'Kuravi'),
#  Text(270, 0, 'Kusumanchi'),
#  Text(271, 0, 'Laxmanchanda'),
#  Text(272, 0, 'Laxmidevipally'),
#  Text(273, 0, 'Lingalaghanpur'),
#  Text(274, 0, 'Lingampet'),
#  Text(275, 0, 'Lingapur'),
#  Text(276, 0, 'Lokeshwaram'),
#  Text(277, 0, 'Luxettipet'),
#  Text(278, 0, 'Machareddy'),
#  Text(279, 0, 'Madanapur'),
#  Text(280, 0, 'Maddirala'),
#  Text(281, 0, 'Maddur'),
#  Text(282, 0, 'Maddur'),
#  Text(283, 0, 'Madgul'),
#  Text(284, 0, 'Madhira'),
#  Text(285, 0, 'Madnur'),
#  Text(286, 0, 'Madugulapally'),
#  Text(287, 0, 'Maganoor'),
#  Text(288, 0, 'Mahabubabad'),
#  Text(289, 0, 'Mahabubnagar_Urban'),
#  Text(290, 0, 'Mahadevpur'),
#  Text(291, 0, 'Maheswaram'),
#  Text(292, 0, 'Makloor'),
#  Text(293, 0, 'Makthal'),
#  Text(294, 0, 'Maldakal'),
#  Text(295, 0, 'Malharrao'),
#  Text(296, 0, 'Malkajgiri'),
#  Text(297, 0, 'Mallapur'),
#  Text(298, 0, 'Mallial'),
#  Text(299, 0, 'Mamda'),
#  Text(300, 0, 'Manakondur'),
#  Text(301, 0, 'Manchal'),
#  Text(302, 0, 'Mancherial'),
#  Text(303, 0, 'Mandamarri'),
#  Text(304, 0, 'Mangapet'),
#  Text(305, 0, 'Manoor'),
#  Text(306, 0, 'Manopad'),
#  Text(307, 0, 'Manthani'),
#  Text(308, 0, 'Manuguru'),
#  Text(309, 0, 'Maredpally'),
#  Text(310, 0, 'Marikal'),
#  Text(311, 0, 'Maripeda'),
#  Text(312, 0, 'Markook'),
#  Text(313, 0, 'Marpalle'),
#  Text(314, 0, 'Marriguda'),
#  Text(315, 0, 'Mattampalli'),
#  Text(316, 0, 'Medak'),
#  Text(317, 0, 'Medchal'),
#  Text(318, 0, 'Medipalle'),
#  Text(319, 0, 'Medipally'),
#  Text(320, 0, 'Mellachervu'),
#  Text(321, 0, 'Mendora'),
#  Text(322, 0, 'Metpalli'),
#  Text(323, 0, 'Midjil'),
#  Text(324, 0, 'Mirdoddi'),
#  Text(325, 0, 'Miryalaguda'),
#  Text(326, 0, 'Mogudampally'),
#  Text(327, 0, 'Mogullapally'),
#  Text(328, 0, 'Moinabad'),
#  Text(329, 0, 'Mominpet'),
#  Text(330, 0, 'Moosapet'),
#  Text(331, 0, 'Morthad'),
#  Text(332, 0, 'Motakondur'),
#  Text(333, 0, 'Mothey'),
#  Text(334, 0, 'Mothkur'),
#  Text(335, 0, 'Mudhole'),
#  Text(336, 0, 'Mudigonda'),
#  Text(337, 0, 'Mugpal'),
#  Text(338, 0, 'Mulakalapally'),
#  Text(339, 0, 'Mulug'),
#  Text(340, 0, 'Mulug'),
#  Text(341, 0, 'Munagala'),
#  Text(342, 0, 'Munipally'),
#  Text(343, 0, 'Munugode'),
#  Text(344, 0, 'Mupkal'),
#  Text(345, 0, 'Musheerabad'),
#  Text(346, 0, 'Mustabad'),
#  Text(347, 0, 'Mutharam_Mahadevpur'),
#  Text(348, 0, 'Mutharam_Manthani'),
#  Text(349, 0, 'Nadigudem'),
#  Text(350, 0, 'Nagalgidda'),
#  Text(351, 0, 'Nagaram'),
#  Text(352, 0, 'Nagi_Reddypet'),
#  Text(353, 0, 'Nakrekal'),
#  Text(354, 0, 'Nalgonda'),
#  Text(355, 0, 'Nallabelli'),
#  Text(356, 0, 'Nampally'),
#  Text(357, 0, 'Nampally'),
#  Text(358, 0, 'Nandigama'),
#  Text(359, 0, 'Nandipet'),
#  Text(360, 0, 'Nangnoor'),
#  Text(361, 0, 'Narayanapoor'),
#  Text(362, 0, 'Narayankhed'),
#  Text(363, 0, 'Narayanpet'),
#  Text(364, 0, 'Narketpally'),
#  Text(365, 0, 'Narmetta'),
#  Text(366, 0, 'Narnoor'),
#  Text(367, 0, 'Narsampet'),
#  Text(368, 0, 'Narsapur'),
#  Text(369, 0, 'Narsapur_G'),
#  Text(370, 0, 'Narsimhulapet'),
#  Text(371, 0, 'Narsingi'),
#  Text(372, 0, 'Narva'),
#  Text(373, 0, 'Naspur'),
#  Text(374, 0, 'Nasurullabad'),
#  Text(375, 0, 'Navipet'),
#  Text(376, 0, 'Nawabpet'),
#  Text(377, 0, 'Nawabpet'),
#  Text(378, 0, 'Nekkonda'),
#  Text(379, 0, 'Nelakondapally'),
#  Text(380, 0, 'Nellikudur'),
#  Text(381, 0, 'Nennel'),
#  Text(382, 0, 'Neradigonda'),
#  Text(383, 0, 'Nereducherla'),
#  Text(384, 0, 'Neredugommu'),
#  Text(385, 0, 'Nidamanoor'),
#  Text(386, 0, 'Nirmal'),
#  Text(387, 0, 'Nirmal Rural'),
#  Text(388, 0, 'Nizamabad North'),
#  Text(389, 0, 'Nizamabad Rural'),
#  Text(390, 0, 'Nizamabad South'),
#  Text(391, 0, 'Nizampet'),
#  Text(392, 0, 'Nizamsagar'),
#  Text(393, 0, 'Noothankal'),
#  Text(394, 0, 'Nyalkal'),
#  Text(395, 0, 'Odela'),
#  Text(396, 0, 'Padara'),
#  Text(397, 0, 'Palakeedu'),
#  Text(398, 0, 'Palakurthy'),
#  Text(399, 0, 'Palakurthy'),
#  Text(400, 0, 'Palmela'),
#  Text(401, 0, 'Palvancha'),
#  Text(402, 0, 'Pangal'),
#  Text(403, 0, 'Papannapet'),
#  Text(404, 0, 'Pargi'),
#  Text(405, 0, 'Parkal'),
#  Text(406, 0, 'Parvathagiri'),
#  Text(407, 0, 'Patancheruvu'),
#  Text(408, 0, 'Pebbair'),
#  Text(409, 0, 'Peda Adisharla Palli'),
#  Text(410, 0, 'Pedda Kodapgal'),
#  Text(411, 0, 'Peddakothapalle'),
#  Text(412, 0, 'Peddamandaddi'),
#  Text(413, 0, 'Peddapalli'),
#  Text(414, 0, 'Peddavangara'),
#  Text(415, 0, 'Peddavoora'),
#  Text(416, 0, 'Peddemul'),
#  Text(417, 0, 'Pegadapalli'),
#  Text(418, 0, 'Pembi'),
#  Text(419, 0, 'Penchikalpet'),
#  Text(420, 0, 'Penpahad'),
#  Text(421, 0, 'Pentlavelli'),
#  Text(422, 0, 'Penuballi'),
#  Text(423, 0, 'Pinapaka'),
#  Text(424, 0, 'Pudur'),
#  Text(425, 0, 'Pulkal'),
#  Text(426, 0, 'Quthbullapur'),
#  Text(427, 0, 'Raghunadhapalem'),
#  Text(428, 0, 'Ragunathpally'),
#  Text(429, 0, 'Raikal'),
#  Text(430, 0, 'Raikode'),
#  Text(431, 0, 'Raiparthy'),
#  Text(432, 0, 'Raipole'),
#  Text(433, 0, 'Rajampet'),
#  Text(434, 0, 'Rajapeta'),
#  Text(435, 0, 'Rajapur'),
#  Text(436, 0, 'Rajendranagar'),
#  Text(437, 0, 'Rajoli'),
#  Text(438, 0, 'Ramachandrapuram'),
#  Text(439, 0, 'Ramadugu'),
#  Text(440, 0, 'Ramagiri'),
#  Text(441, 0, 'Ramagundam'),
#  Text(442, 0, 'Ramannapet'),
#  Text(443, 0, 'Ramareddy'),
#  Text(444, 0, 'Ramayampet'),
#  Text(445, 0, 'Rebbena'),
#  Text(446, 0, 'Regode'),
#  Text(447, 0, 'Regonda'),
#  Text(448, 0, 'Renjal'),
#  Text(449, 0, 'Revally'),
#  Text(450, 0, 'Rudrangi'),
#  Text(451, 0, 'Rudrur'),
#  Text(452, 0, 'Sadashivnagar'),
#  Text(453, 0, 'Sadasivpet'),
#  Text(454, 0, 'Saidabad'),
#  Text(455, 0, 'Sangareddy'),
#  Text(456, 0, 'Sangem'),
#  Text(457, 0, 'Sarangapur'),
#  Text(458, 0, 'Sarangapur'),
#  Text(459, 0, 'Sathupally'),
#  Text(460, 0, 'Secunderabad'),
#  Text(461, 0, 'Serilingampalle'),
#  Text(462, 0, 'Shabad'),
#  Text(463, 0, 'Shaikpet'),
#  Text(464, 0, 'Shaligouraram'),
#  Text(465, 0, 'Shamirpet'),
#  Text(466, 0, 'Shamshabad'),
#  Text(467, 0, 'Shankarampet_A'),
#  Text(468, 0, 'Shankarapatnam'),
#  Text(469, 0, 'Shankarpalle'),
#  Text(470, 0, 'Shayampet'),
#  Text(471, 0, 'Shivampet'),
#  Text(472, 0, 'Siddipet_Rural'),
#  Text(473, 0, 'Siddipet_Urban'),
#  Text(474, 0, 'Singareni'),
#  Text(475, 0, 'Sircilla'),
#  Text(476, 0, 'Sirgapoor'),
#  Text(477, 0, 'Sirikonda'),
#  Text(478, 0, 'Sirikonda'),
#  Text(479, 0, 'Sirpur_T'),
#  Text(480, 0, 'Sirpur_U'),
#  Text(481, 0, 'Soan'),
#  Text(482, 0, 'Srirampur'),
#  Text(483, 0, 'Srirangapur'),
#  Text(484, 0, 'Sujathanagar'),
#  Text(485, 0, 'Sultanabad'),
#  Text(486, 0, 'Suryapet'),
#  Text(487, 0, 'Tadoor'),
#  Text(488, 0, 'Tadvai (Sammakka Sarakka)'),
#  Text(489, 0, 'Tadwai'),
#  Text(490, 0, 'Talakondapally'),
#  Text(491, 0, 'Talamadugu'),
#  Text(492, 0, 'Tamsi'),
#  Text(493, 0, 'Tandur'),
#  Text(494, 0, 'Tandur'),
#  Text(495, 0, 'Tanoor'),
#  Text(496, 0, 'Tekmal'),
#  Text(497, 0, 'Tekulapalle'),
#  Text(498, 0, 'Tekumatla'),
#  Text(499, 0, 'Telkapalle'),
#  Text(500, 0, 'Thallada'),
#  Text(501, 0, 'Thangallapalli'),
#  Text(502, 0, 'Tharigoppula'),
#  Text(503, 0, 'Thimmajipeta'),
#  Text(504, 0, 'Thimmapur'),
#  Text(505, 0, 'Thoguta'),
#  Text(506, 0, 'Thorrur'),
#  Text(507, 0, 'Thungathurthy'),
#  Text(508, 0, 'Tipparthy'),
#  Text(509, 0, 'Tirumalagiri'),
#  Text(510, 0, 'Tirumalagiri_Sagar'),
#  Text(511, 0, 'Tirumalayapalem'),
#  Text(512, 0, 'Tirumalgiri'),
#  Text(513, 0, 'Tiryani'),
#  Text(514, 0, 'Tripuraram'),
#  Text(515, 0, 'Turkapalle_M'),
#  Text(516, 0, 'Undavelly'),
#  Text(517, 0, 'Uppal'),
#  Text(518, 0, 'Uppunuthala'),
#  Text(519, 0, 'Urkonda'),
#  Text(520, 0, 'Utnur'),
#  Text(521, 0, 'V_Saidapur'),
#  Text(522, 0, 'Vailpur'),
#  Text(523, 0, 'Valigonda'),
#  Text(524, 0, 'Vangoor'),
#  Text(525, 0, 'Varni'),
#  Text(526, 0, 'Vatpally'),
#  Text(527, 0, 'Veenavanka'),
#  Text(528, 0, 'Veernapalli'),
#  Text(529, 0, 'Velair'),
#  Text(530, 0, 'Veldanda'),
#  Text(531, 0, 'Velgatur'),
#  Text(532, 0, 'Vemanpalle'),
#  Text(533, 0, 'Vemsoor'),
#  Text(534, 0, 'Vemulapally'),
#  Text(535, 0, 'Vemulawada'),
#  Text(536, 0, 'Vemulawada Rural'),
#  Text(537, 0, 'Venkatapur'),
#  Text(538, 0, 'Venkatapuram'),
#  Text(539, 0, 'Vikarabad'),
#  Text(540, 0, 'Waddepally'),
#  Text(541, 0, 'Wanaparthy'),
#  Text(542, 0, 'Wankidi'),
#  Text(543, 0, 'Warangal'),
#  Text(544, 0, 'Wardhannapet'),
#  Text(545, 0, 'Wargal'),
#  Text(546, 0, 'Weepangandla'),
#  Text(547, 0, 'Wyra'),
#  Text(548, 0, 'Yacharam'),
#  Text(549, 0, 'Yadagirigutta'),
#  Text(550, 0, 'Yedapally'),
#  Text(551, 0, 'Yelal'),
#  Text(552, 0, 'Yeldurthy'),
#  Text(553, 0, 'Yellandu'),
#  Text(554, 0, 'Yellareddy'),
#  Text(555, 0, 'Yellareddypet'),
#  Text(556, 0, 'Yergatla'),
#  Text(557, 0, 'Yerrupalem'),
#  Text(558, 0, 'Zaffergadh'),
#  Text(559, 0, 'Zahirabad'),
#  Text(560, 0, 'Lingal'),
#  Text(561, 0, 'Nagar_Kurnool'),
#  Text(562, 0, 'Mahabubnagar_Rural'),
#  Text(563, 0, 'Utkoor'),
#  Text(564, 0, 'Saroornagar'),
#  Text(565, 0, 'Ameenpur'),
#  Text(566, 0, 'Jinnaram'),
#  Text(567, 0, 'Toopran'),
#  Text(568, 0, 'Manoharabad'),
#  Text(569, 0, 'Doultabad'),
#  Text(570, 0, 'Chilipched'),
#  Text(571, 0, 'Shankarampet_R'),
#  Text(572, 0, 'Chegunta'),
#  Text(573, 0, 'Domakonda'),
#  Text(574, 0, 'Pitlam'),
#  Text(575, 0, 'Bichkunda'),
#  Text(576, 0, 'Birkoor'),
#  Text(577, 0, 'Mavala'),
#  Text(578, 0, 'Anthergaon'),
#  Text(579, 0, 'Wazeed'),
#  Text(580, 0, 'Kammarpally'),
#  Text(581, 0, 'Kodakandla'),
#  Text(582, 0, 'Krishna'),
#  Text(583, 0, 'Kotapalle'),
#  Text(584, 0, 'Nadikuda'),
#  Text(585, 0, 'Muduchinthalaphally'),
#  Text(586, 0, 'Narayanraopet'),
#  Text(587, 0, 'Mosra'),
#  Text(588, 0, 'Chandur'),
#  Text(589, 0, 'Chowtakur'),
#  Text(590, 0, 'Masaipet'),
#  Text(591, 0, 'Dhoolumitta')]
