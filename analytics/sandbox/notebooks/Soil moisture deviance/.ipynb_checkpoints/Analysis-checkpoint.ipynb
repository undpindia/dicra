# %% [markdown]
# # Statewise Soil Moisture deviance analysis
# This is notebook 2 of the project.

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot
import seaborn as sns
import pandas
import rasterio
from osgeo import gdal
import geopandas as gpd
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("StateWiseData/MaharashtraData.csv")
df.columns = df.columns.map(str)
df.head(2)
# Out:
#    index         0         1         2         3         4         5  \
# 0      0  2.549002  2.829386  2.829386  3.751292  4.225150  2.257778
# 1      1  4.188626  3.091398  3.091398  4.527487  6.681919  4.198399
#
#           6         7         8  ...      1994      1995      1996      1997  \
# 0  3.173797  3.163928  3.163928  ...  2.116667  2.116667  2.357201  1.847273
# 1  3.451913  2.927097  2.927097  ...  7.561326  7.561326  5.984145  6.350387
#
#        1998      1999      2000      2001      2002      2003
# 0  1.847273  2.178894  2.532894  2.532894  2.125161  2.192698
# 1  1.847273  2.982864  5.280305  5.280305  7.252660  2.364489
#
# [2 rows x 2005 columns]

# %%
data_len = int(len(df.columns))-1
print(data_len)
# Out:
# 2004

# %% [markdown]
# ## Visualizing Soil moisture data
# Some visualizations to better understand the trends visible in data.

# %%
#plotting Moisture trends in 3 random pixels
fig, ax = plt.subplots(3, figsize=(10, 10))
for i in range(0,3):
    ax[i].plot(df[str(i*10)])

# %%
#plotting pixel wise soil moisture values from 2015 and 2022 to see any changes.
f, ax = plt.subplots(figsize=(19, 8))
state_mar_2015 = np.array(df.iloc[0])
state_mar_2022 =  np.array(df.iloc[-1])

first_last = pd.DataFrame()
first_last["2015"] = state_mar_2015
first_last["2022"] = state_mar_2022
first_last["pixel"] = first_last.index
first_last.plot(ax=ax,label ='Soil moisture value', x = "pixel")

plt.xlabel('Pixel (denotes a geographical region)')
plt.ylabel('Soil Moisture content')
plt.title('Comparision between soil moisture values of a geopgraphical region 7 years apart')
# Out:
# Text(0.5, 1.0, 'Comparision between soil moisture values of a geopgraphical region 7 years apart')

# %% [markdown]
# ## Calculating Deviances
# For Every pixel value of the geography, we calculate a deviance score using Linear Regression, considering the period of 84 months starting from March 2015 to March 2022.

# %%
scores = []

for i in range(0,data_len):
    
    X = np.array(df['index'])
    #print(X)
    X = X.reshape(-1, 1)
    #print(X)
    i = str(i)
    #print(df[i])
    y = np.array(df[i])
    y = y.reshape(-1, 1)

    #Perform Linear Regression and obtain the slope
    reg = LinearRegression().fit(X, y)
    y_pred_trend = reg.predict(X)
    slope, intercept = np.polyfit(np.array(df['index']), y_pred_trend,1)
    line_slope = slope[0]

    scores.append(line_slope)

# %%
len(scores)
# Out:
# 2004

# %%
#Imbibe score values into the coordinates
coordinates = pd.read_csv("StateCoordinates//Maharashtracoordinates.csv")
coordinates["values"] = scores
coordinates["latitude"] = coordinates["y"]
coordinates["longitude"] = coordinates["x"]

# %%
print("max:", coordinates["values"].max(), "min:", coordinates["values"].min())
# Out:
# max: 0.05355540844898031 min: -0.044048973212461706

# %%
import rioxarray
df2 = coordinates[['latitude','longitude']]
df2['value'] = list(coordinates['values'])
da = df2.set_index(['latitude', 'longitude']).to_xarray()
da = da.set_coords(['latitude', 'longitude'])
da.rio.to_raster('MaharashtraSoilMoistureDeviance.tif')
# Out:
# C:\Users\007sh\AppData\Local\Temp\ipykernel_12928\4275142142.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['value'] = list(coordinates['values'])

# %% [markdown]
# ### Visualizing the Deviance (Change in soil moisture over 7 years) in Soil Moisture
# These visualizations contain change in soil moisture (deviance) over seven years from Mar 2022 to Mar 2022.

# %%
from osgeo import gdal
import matplotlib.pyplot as plt
from osgeo import osr

spatref = osr.SpatialReference()
spatref.ImportFromEPSG(4326)
crs_wkt = spatref.ExportToWkt()

dataset = gdal.Open('MaharashtraSoilMoistureDeviance.tif', gdal.GA_ReadOnly) 
dataset.SetProjection(crs_wkt)
band = dataset.GetRasterBand(1)
arr = band.ReadAsArray()

# %%
geotransform = dataset.GetGeoTransform()

originX,pixelWidth,empty,finalY,empty2,pixelHeight=geotransform
cols =  dataset.RasterXSize
rows =  dataset.RasterYSize

projection = dataset.GetProjection()

finalX = originX + pixelWidth * cols
originY = finalY + pixelHeight * rows

extentArray = [originX,finalX,originY,finalY]

plt.figure(figsize=(9,9))

im = plt.imshow(arr, cmap= "RdYlGn", extent=extentArray, origin="lower")
plt.colorbar(im, fraction=0.03)
#plt.gca().invert_yaxis()

plt.rcParams.update({'font.size': 13})
plt.title("Deviance in soil moisture content for Maharashtra (2015-2022)\n")
plt.xlabel('Longitude')
plt.ylabel('Latitude')
print(" ")
plt.show()
