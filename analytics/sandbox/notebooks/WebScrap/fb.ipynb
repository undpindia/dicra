# %%
from facebook_scraper import get_posts
 
listposts = []
for post in get_posts("UNDPinIndia", pages=100):  #reading 100 pages
    #print(post['text'][:50])
    listposts.append(post)

# %%
import pandas as pd
df = pd.DataFrame(listposts)

# %%
df #articles till june 25 2022
# Out:
#               post_id                                               text  \
# 0    5284387598318513
# 1    5662318483858754  The world is facing a dual climate and nature ...
# 2    5659981074092495  🧑🏽‍💻👩🏽‍💻 Youth Co:Lab India 2022 - 23 is now L...
# 3    5659877654102837  Youth are the #AgentsOfChange 🧑🏽‍🤝‍🧑🏽.\n\nThis...
# 4    5659693410787928  "Why is the 'kalavastha' (climate in Malayalam...
# ..                ...                                                ...
# 391  5168877093202898  #MSMEs 🏢 are the lifeline of 🇮🇳’s economy.\n\n...
# 392  5166284623462145  From artists👩🏾‍🎨 to entrepreneurs👩🏾‍💼!\n\nIn #...
# 393  5165703153520292  Making way for #GenerationEquality 🏳️‍🌈.\n\nTo...
# 394  5163437003746907  Find time to exercise this Sunday!\n\nRegular ...
# 395  5160263337397607  Making way for #GenerationEquality 🏳️‍🌈.\n\nTo...
#
#                                              post_text shared_text  \
# 0                                                             None
# ...
