# %%
import geopandas as gpd
import pandas as pd
import rasterio


import os
import matplotlib.pyplot as plt
import rasterio
from statsmodels.tsa.seasonal import STL
import numpy as np
from sklearn.linear_model import LinearRegression
import datetime as dt
from matplotlib.colors import TwoSlopeNorm
import time

import warnings

# fubnctions file
import dppd

# %%
mh_dist = gpd.read_file('Maharashtra/District.geojson')
mh_dist = mh_dist.reset_index()

mh_village = gpd.read_file('Maharashtra/Villages.geojson')
mh_village = mh_village.reset_index()

mh_taluk= gpd.read_file('Maharashtra/Taluk.geojson')
mh_taluk = mh_taluk.reset_index()

ka_dist = gpd.read_file('Karnataka/District.geojson')
ka_dist = ka_dist.reset_index()

ka_village = gpd.read_file('Karnataka/Villages.geojson')
ka_village = ka_village.reset_index()

ka_taluk = gpd.read_file('Karnataka/Taluk.geojson')
ka_taluk = ka_taluk.reset_index()

# %%
figure, DPPD_df_mh_dist = dppd.fire_counts(2012, 2021, mh_dist, ' MH Districts')
figure, DPPD_df_mh_taluk = dppd.fire_counts(2012, 2021, mh_taluk, 'MH Taluk')
figure, DPPD_df_mh_village = dppd.fire_counts(2012, 2021, mh_village, 'MH Villages')
figure, DPPD_df_ka_dist = dppd.fire_counts(2012, 2021, ka_dist, ' KA Districts')
figure, DPPD_df_ka_taluk = dppd.fire_counts(2012, 2021, ka_taluk, ' KA Taluk')
figure, DPPD_df_ka_village = dppd.fire_counts(2012, 2021, ka_village, 'KA Villages')
# Out:
# Scores are calculated in 0.15787309408187866  minutes
# Scores are calculated in 0.12864534854888915  minutes
# Scores are calculated in 5.419415060679118  minutes
# Scores are calculated in 1.260342280069987  minutes
# Scores are calculated in 0.6664818445841472  minutes
# Scores are calculated in 3.7924558838208515  minutes
